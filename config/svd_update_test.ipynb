# %%
from pylab import *
from SVDUpdate import *

# %%
x = arange (0,10,0.1)

# %%
def y(t,f,a,tau,phi):
    return a*exp(-t/tau)*sin(2*pi*f*x+phi)

# %%
plot(x,y(x,1.0,1.0,3,0))
show()

# %%
y_stack = y(x,1.0,1.0,3,0)
for i in arange(1000):
    y_stack = vstack([y_stack,y(x,1.0*(0.9+rand()/5),1.0*(0.9+rand()/5),3*(0.9+rand()/5),0)])

# %%
y_stack.shape
# Out:
# (1001, 100)

# %%
plot(y_stack[0])
show()

# %%
u,s,v = svd(y_stack[:4],full_matrices=False)

# %%
plot(v[0])
show()

# %%
"""" sage: X = np.array([[1.0,2.0,3.0,4.0],[3.0,2.0,5.0,5.0],[5.0,3.0,1.0,1.0],[7.0,7.0,7.0,7.0]])
    sage: U, s, V = np.linalg.svd(X, full_matrices = False)
    sage: a = np.reshape(np.array([4.0,5.0,1.0,7.0]), (-1, 1))
    sage: U, S, V = svd_update(U, np.diag(s), V, X, a, update = True)
    Downdate
    sage: X = np.array([[1.0,2.0,3.0,4.0],[3.0,2.0,5.0,5.0],[5.0,3.0,1.0,1.0],[7.0,7.0,7.0,7.0]])
    sage: U, s, V = np.linalg.svd(X, full_matrices = False)
    sage: U, S, V = svd_update(U, np.diag(s), V, X, downdate = True)
    Revise
    sage: X = np.array([[1.0,2.0,3.0,4.0],[3.0,2.0,5.0,5.0],[5.0,3.0,1.0,1.0],[7.0,7.0,7.0,7.0]])
    sage: U, s, V = np.linalg.svd(X, full_matrices = False)
    sage: a = np.reshape(np.array([4.0,5.0,1.0,7.0]), (-1, 1))
    sage: U, S, V = svd_update(U, np.diag(s), V, X, a)
    Recenter
    sage: X = np.array([[1.0,2.0,3.0,4.0],[3.0,2.0,5.0,5.0],[5.0,3.0,1.0,1.0],[7.0,7.0,7.0,7.0]])
    sage: U, s, V = np.linalg.svd(X, full_matrices = False)
    sage: U, S, V = svd_update(U, np.diag(s), V, X)
"""
# Out:
# '" sage: X = np.array([[1.0,2.0,3.0,4.0],[3.0,2.0,5.0,5.0],[5.0,3.0,1.0,1.0],[7.0,7.0,7.0,7.0]])\n    sage: U, s, V = np.linalg.svd(X, full_matrices = False)\n    sage: a = np.reshape(np.array([4.0,5.0,1.0,7.0]), (-1, 1))\n    sage: U, S, V = svd_update(U, np.diag(s), V, X, a, update = True)\n    Downdate\n    sage: X = np.array([[1.0,2.0,3.0,4.0],[3.0,2.0,5.0,5.0],[5.0,3.0,1.0,1.0],[7.0,7.0,7.0,7.0]])\n    sage: U, s, V = np.linalg.svd(X, full_matrices = False)\n    sage: U, S, V = svd_update(U, np.diag(s), V, X, downdate = True)\n    Revise\n    sage: X = np.array([[1.0,2.0,3.0,4.0],[3.0,2.0,5.0,5.0],[5.0,3.0,1.0,1.0],[7.0,7.0,7.0,7.0]])\n    sage: U, s, V = np.linalg.svd(X, full_matrices = False)\n    sage: a = np.reshape(np.array([4.0,5.0,1.0,7.0]), (-1, 1))\n    sage: U, S, V = svd_update(U, np.diag(s), V, X, a)\n    Recenter\n    sage: X = np.array([[1.0,2.0,3.0,4.0],[3.0,2.0,5.0,5.0],[5.0,3.0,1.0,1.0],[7.0,7.0,7.0,7.0]])\n    sage: U, s, V = np.linalg.svd(X, full_matrices = False)\n    sage: U, S, V = svd_update(U, np.diag(s), V, X)\n'

# %%
a = np.reshape(np.array(y_stack[:5]), (-1, 1))
u_new,s_new,v_new = svd_update(u,diag(s),v,y_stack,a,update=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-2cb23c254b4f> in <module>()
#       1 a = np.reshape(np.array(y_stack[:5]), (-1, 1))
# ----> 2 u_new,s_new,v_new = svd_update(u,diag(s),v,y_stack,a,update=True)
#
# /reg/neh/home5/sioan/Desktop/git_version_controlled/auto_xtc_hdf5_converter/config/SVDUpdate.py in svd_update(U, S, V, X, c, update, downdate)
#     104         a = np.reshape(np.multiply((-1/X.shape[1]), np.dot(X, b)), (-1, 1))
#     105
# --> 106     m = np.reshape(np.dot(np.transpose(U), a), (-1, 1))
#     107     p = np.reshape(a - np.dot(U, m), (-1, 1))
#     108     Ra = np.linalg.norm(p)
#
# ValueError: shapes (4,4) and (500,1) not aligned: 4 (dim 1) != 500 (dim 0)

# %%
X = np.array([[1.0,2.0,3.0,4.0],[3.0,2.0,5.0,5.0],[5.0,3.0,1.0,1.0],[7.0,7.0,7.0,7.0]])
U, s, V = np.linalg.svd(X, full_matrices = False)
a = np.reshape(np.array([4.0,5.0,1.0,7.0]), (-1, 1))
U, S, V = svd_update(U, np.diag(s), V, X, a, update = True)

# %%
X = y_stack[:5]
U, s, V = np.linalg.svd(X, full_matrices = False)
a = np.reshape(np.array(y_stack[6]), (-1, 1))
U, S, V = svd_update(U, np.diag(s), V, X, a, update = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-7c0bb8bd1fb9> in <module>()
#       2 U, s, V = np.linalg.svd(X, full_matrices = False)
#       3 a = np.reshape(np.array(y_stack[6]), (-1, 1))
# ----> 4 U, S, V = svd_update(U, np.diag(s), V, X, a, update = True)
#
# /reg/neh/home5/sioan/Desktop/git_version_controlled/auto_xtc_hdf5_converter/config/SVDUpdate.py in svd_update(U, S, V, X, c, update, downdate)
#     104         a = np.reshape(np.multiply((-1/X.shape[1]), np.dot(X, b)), (-1, 1))
#     105
# --> 106     m = np.reshape(np.dot(np.transpose(U), a), (-1, 1))
#     107     p = np.reshape(a - np.dot(U, m), (-1, 1))
#     108     Ra = np.linalg.norm(p)
#
# ValueError: shapes (5,5) and (100,1) not aligned: 5 (dim 1) != 100 (dim 0)

# %%
np.array([[1.0,2.0,3.0,4.0],[3.0,2.0,5.0,5.0],[5.0,3.0,1.0,1.0],[7.0,7.0,7.0,7.0]]).shape
# Out:
# (4, 4)
